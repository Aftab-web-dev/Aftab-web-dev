# %% [markdown]
# <a href="https://colab.research.google.com/github/Aftab-web-dev/Aftab-web-dev/blob/main/linearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
from sklearn.linear_model import LinearRegression

print("Aftab shaikh")
feature_set = []
target = []

rows = 200
limit = 2000
count = 0
for i in range(0,rows):
  x = random.randint(0,limit)
  y = random.randint(0,limit)
  z = random.randint(0,limit)
  feature_set.append([x,y,z])
  g = 8*x + 10*y + 3*z
  target.append(g)

  count = count + 1
print("Total Records", count)

print("Feature set:" , feature_set)

print("Target: " , target)

model = LinearRegression()

model.fit(feature_set,target)

test_data = [[1,1,1]]
prediction = model.predict(test_data)
print('Prediction:'+str(prediction)+'\t'+"Coefficient:"+str(model.coef_))

print("Aftab shaikh")
# Out:
# Aftab shaikh
# Total Records 200
# ...
